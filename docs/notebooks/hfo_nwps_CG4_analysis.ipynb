# %%
import xarray as xr

# NWPS model run from site: HFO (Hawaii), CG: 4 (Maui)
# download an example at: https://nomads.ncep.noaa.gov/gribfilter.php?ds=prnwps
# and set the following filename below to the downloaded one. place the downloaded 
# file into the notebooks/ dir for this ipynb to access it.

# NOTE: idx file created by grib engine or pygrib to improve read speed, 
# so when we need to refresh the data from the next model run, remove idx as well.

maui_grib2 = 'hfo_nwps_CG4_20251114_1200.grib2'

# %%
an_ds = xr.open_dataset(
    maui_grib2,
    engine="cfgrib",
    filter_by_keys={'dataType': 'an'}
) 

fc_ds = xr.open_dataset(
    maui_grib2,
    engine="cfgrib",
    filter_by_keys={'dataType': 'fc'}
)

# %% [markdown]
# ## initial dataset exploration

# %%
# analysis dataset 

# the model's t-0 run, since no steps exist,
# model run is generated directly from current data sources, 
# most accurate representation. due to model delays though 
# and when the grib2 file actually becomes accessible, 
# this dataType is probably not needed.

an_ds
# Out:
# <xarray.Dataset> Size: 622kB
# Dimensions:     (latitude: 109, longitude: 158)
# Coordinates:
#   * latitude    (latitude) float64 872B 20.55 20.56 20.56 ... 21.03 21.04 21.04
#   * longitude   (longitude) float64 1kB 203.3 203.3 203.3 ... 204.0 204.0 204.0
#     time        datetime64[ns] 8B ...
#     step        timedelta64[ns] 8B ...
#     surface     float64 8B ...
#     valid_time  datetime64[ns] 8B ...
# Data variables:
#     swh         (latitude, longitude) float32 69kB ...
#     dirpw       (latitude, longitude) float32 69kB ...
#     perpw       (latitude, longitude) float32 69kB ...
#     shts        (latitude, longitude) float32 69kB ...
#     wdir        (latitude, longitude) float32 69kB ...
#     ws          (latitude, longitude) float32 69kB ...
#     zos         (latitude, longitude) float32 69kB ...
#     dirc        (latitude, longitude) float32 69kB ...
#     spc         (latitude, longitude) float32 69kB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2025-11-15T14:10 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# ### coordinate values of `an_ds`

# %%
# * entails dimensional coordinate
for coord_name in an_ds.coords:
    coord = an_ds.coords[coord_name]
    if coord_name in an_ds.dims:
        print(f"* {coord_name}: {coord.shape}")
    else: 
        print(f" {coord_name}: {coord.values}")
# Out:
#  time: 2025-11-14T12:00:00.000000000
#  step: 0 nanoseconds
#  surface: 0.0
# * latitude: (109,)
# * longitude: (158,)
#  valid_time: 2025-11-14T12:00:00.000000000

# %%
# forecast dataset

# 1hr time steps, 6 day forecast projection from UTC position (i.e. 00Z, 12Z) 
# since grib2 file access for HFO seems to typically be unavailable untill 6-7HR 
# past UTC position, example: grib2 file for 00Z completion is around 06-07Z.  
# could be smart to remove steps from 00Z - 07Z or whenever the new data is accessible. 

fc_ds
# Out:
# <xarray.Dataset> Size: 89MB
# Dimensions:     (step: 144, latitude: 109, longitude: 158)
# Coordinates:
#   * step        (step) timedelta64[ns] 1kB 01:00:00 02:00:00 ... 6 days 00:00:00
#   * latitude    (latitude) float64 872B 20.55 20.56 20.56 ... 21.03 21.04 21.04
#   * longitude   (longitude) float64 1kB 203.3 203.3 203.3 ... 204.0 204.0 204.0
#     time        datetime64[ns] 8B ...
#     surface     float64 8B ...
#     valid_time  (step) datetime64[ns] 1kB ...
# Data variables:
#     swh         (step, latitude, longitude) float32 10MB ...
#     dirpw       (step, latitude, longitude) float32 10MB ...
#     perpw       (step, latitude, longitude) float32 10MB ...
#     shts        (step, latitude, longitude) float32 10MB ...
#     wdir        (step, latitude, longitude) float32 10MB ...
#     ws          (step, latitude, longitude) float32 10MB ...
#     zos         (step, latitude, longitude) float32 10MB ...
#     dirc        (step, latitude, longitude) float32 10MB ...
#     spc         (step, latitude, longitude) float32 10MB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2025-11-15T14:10 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# ### coordinate values of `fc_ds`

# %%
# * entails dimensional coordinate
for coord_name in fc_ds.coords:
    coord = fc_ds.coords[coord_name]
    if coord_name in fc_ds.dims:
        print(f"* {coord_name}: {coord.shape}")
    else: 
        print(f" {coord_name}: {coord.values}")
# Out:
#  time: 2025-11-14T12:00:00.000000000
# * step: (144,)
#  surface: 0.0
# * latitude: (109,)
# * longitude: (158,)
#  valid_time: ['2025-11-14T13:00:00.000000000' '2025-11-14T14:00:00.000000000'
#  '2025-11-14T15:00:00.000000000' '2025-11-14T16:00:00.000000000'
#  '2025-11-14T17:00:00.000000000' '2025-11-14T18:00:00.000000000'
#  '2025-11-14T19:00:00.000000000' '2025-11-14T20:00:00.000000000'
#  '2025-11-14T21:00:00.000000000' '2025-11-14T22:00:00.000000000'
#  '2025-11-14T23:00:00.000000000' '2025-11-15T00:00:00.000000000'
#  '2025-11-15T01:00:00.000000000' '2025-11-15T02:00:00.000000000'
#  '2025-11-15T03:00:00.000000000' '2025-11-15T04:00:00.000000000'
#  '2025-11-15T05:00:00.000000000' '2025-11-15T06:00:00.000000000'
#  '2025-11-15T07:00:00.000000000' '2025-11-15T08:00:00.000000000'
#  '2025-11-15T09:00:00.000000000' '2025-11-15T10:00:00.000000000'
#  '2025-11-15T11:00:00.000000000' '2025-11-15T12:00:00.000000000'
#  '2025-11-15T13:00:00.000000000' '2025-11-15T14:00:00.000000000'
#  '2025-11-15T15:00:00.000000000' '2025-11-15T16:00:00.000000000'
#  '2025-11-15T17:00:00.000000000' '2025-11-15T18:00:00.000000000'
#  '2025-11-15T19:00:00.000000000' '2025-11-15T20:00:00.000000000'
#  '2025-11-15T21:00:00.000000000' '2025-11-15T22:00:00.000000000'
#  '2025-11-15T23:00:00.000000000' '2025-11-16T00:00:00.000000000'
#  '2025-11-16T01:00:00.000000000' '2025-11-16T02:00:00.000000000'
#  '2025-11-16T03:00:00.000000000' '2025-11-16T04:00:00.000000000'
#  '2025-11-16T05:00:00.000000000' '2025-11-16T06:00:00.000000000'
#  '2025-11-16T07:00:00.000000000' '2025-11-16T08:00:00.000000000'
#  '2025-11-16T09:00:00.000000000' '2025-11-16T10:00:00.000000000'
#  '2025-11-16T11:00:00.000000000' '2025-11-16T12:00:00.000000000'
#  '2025-11-19T23:00:00.000000000' '2025-11-20T00:00:00.000000000'
#  '2025-11-20T01:00:00.000000000' '2025-11-20T02:00:00.000000000'
#  '2025-11-20T03:00:00.000000000' '2025-11-20T04:00:00.000000000'
#  '2025-11-20T05:00:00.000000000' '2025-11-20T06:00:00.000000000'
#  '2025-11-20T07:00:00.000000000' '2025-11-20T08:00:00.000000000'
#  '2025-11-20T09:00:00.000000000' '2025-11-20T10:00:00.000000000'
#  '2025-11-20T11:00:00.000000000' '2025-11-20T12:00:00.000000000']

# %% [markdown]
# ### name and unit for data vars

# %%
for var_name in an_ds.data_vars: 
    long_name = an_ds[var_name].attrs.get("long_name", "N/A")
    units = an_ds[var_name].attrs.get("units", "N/A")
    print(f"{var_name}: {long_name}")
    print(f"{var_name}: {units}")
# Out:
# swh: Significant height of combined wind waves and swell
# swh: m
# dirpw: Primary wave direction
# dirpw: Degree true
# perpw: Primary wave mean period
# perpw: s
# shts: Significant height of total swell
# shts: m
# wdir: Wind direction
# wdir: Degree true
# ws: Wind speed
# ws: m s**-1
# zos: Sea surface height
# zos: m
# dirc: Current direction
# dirc: Degree true
# spc: Current speed
# spc: m s**-1

# %% [markdown]
# ### lat and long dim values

# %%
print("Longitude values: ")
for value in fc_ds["longitude"].values:
    print(value)

print ("Latitude values: ")
for value in fc_ds["latitude"].values:
    print(value)
# Out:
# Longitude values:
# 203.1
# 203.10480769230767
# 203.10961538461535
# 203.11442307692303
# 203.1192307692307
# 203.1240384615384
# 203.12884615384607
# 203.13365384615375
# 203.13846153846143
# 203.1432692307691
# 203.1480769230768
# 203.15288461538447
# 203.15769230769214
# 203.16249999999982
# 203.1673076923075
# 203.17211538461518
# 203.17692307692286
# 203.18173076923054
# 203.18653846153822
# 203.1913461538459
# 203.19615384615358
# 203.20096153846126
# 203.20576923076894
# 203.21057692307662
# 203.2153846153843
# 203.22019230769197
# 203.22499999999965
# 203.22980769230733
# 203.234615384615
# 203.2394230769227
# 203.24423076923037
# 203.24903846153805
# 203.25384615384573
# 203.2586538461534
# 203.2634615384611
# 203.26826923076877
# 203.27307692307645
# 203.27788461538412
# 203.2826923076918
# 203.28749999999948
# 203.29230769230716
# 203.29711538461484
# 203.30192307692252
# 203.3067307692302
# 203.31153846153788
# 203.31634615384556
# 203.32115384615324
# 203.32596153846092
# 203.3307692307686
# 203.33557692307627
# 203.34038461538395
# 203.34519230769163
# 203.3499999999993
# 203.354807692307
# 203.35961538461467
# 203.36442307692235
# 203.36923076923003
# 203.3740384615377
# 203.3788461538454
# 203.38365384615307
# 203.38846153846075
# 203.39326923076842
# 203.3980769230761
# 203.40288461538378
# 203.40769230769146
# 203.41249999999914
# 203.41730769230682
# 203.4221153846145
# 203.42692307692218
# 203.43173076922986
# 203.43653846153754
# 203.44134615384522
# 203.4461538461529
# 203.45096153846058
# 203.45576923076825
# 203.46057692307593
# 203.4653846153836
# 203.4701923076913
# 203.47499999999897
# 203.47980769230665
# 203.48461538461433
# 203.489423076922
# 203.4942307692297
# 203.49903846153737
# 203.50384615384505
# 203.50865384615273
# 203.5134615384604
# 203.51826923076808
# 203.52307692307576
# 203.52788461538344
# 203.53269230769112
# 21.310010000000354
# 21.314515000000355
# 21.319020000000357
# 21.32352500000036
# 21.32803000000036
# 21.332535000000362
# 21.337040000000364
# 21.341545000000366
# 21.346050000000368
# 21.35055500000037
# 21.35506000000037
# 21.359565000000373
# 21.364070000000375
# 21.368575000000376
# 21.373080000000378
# 21.37758500000038
# 21.38209000000038
# 21.386595000000383
# 21.391100000000385
# 21.395605000000387
# 21.4

# %% [markdown]
# ### all messages in grib2 file

# %%
import pygrib

# %%
an_grbs = pygrib.open(maui_grib2)

# %%
# start at first message
an_grbs.seek(0)

# %%
for grb in an_grbs: 
    print(grb)

# %% [markdown]
# # example data fetch for a surf spot

# %%
# for reference, using coords for ho'okipa, at the Point (leftmost peaks) 
# (-156.3596 20.9342) -> 203.6431

hookipa = { 
    "longitude": 203.6431,  
    "latitude": 20.9432
}

hookipa_spot_data = fc_ds.sel(
    latitude=hookipa["latitude"],
    longitude=hookipa["longitude"], 
    method="nearest"
)

print(hookipa_spot_data)
# Out:
# <xarray.Dataset> Size: 8kB
# Dimensions:     (step: 144)
# Coordinates:
#   * step        (step) timedelta64[ns] 1kB 01:00:00 02:00:00 ... 6 days 00:00:00
#     time        datetime64[ns] 8B 2025-11-13T12:00:00
#     surface     float64 8B 0.0
#     latitude    float64 8B 20.95
#     longitude   float64 8B 203.6
#     valid_time  (step) datetime64[ns] 1kB 2025-11-13T13:00:00 ... 2025-11-19T...
# Data variables:
#     swh         (step) float32 576B ...
#     dirpw       (step) float32 576B ...
#     perpw       (step) float32 576B ...
#     shts        (step) float32 576B ...
#     wdir        (step) float32 576B ...
#     ws          (step) float32 576B ...
#     zos         (step) float32 576B ...
#     dirc        (step) float32 576B ...
#     spc         (step) float32 576B ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2025-11-14T12:11 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# # overall summary notes
#
# ## x-array vs pygrib
#
# x-array lazy loading is clutch, should reduce memory load and still allow me to search and pull specific
# values from lat / long w/ nearest neighbor selection. nearest neighbor probably makes the most sense,
# since bathymetry alongside coastline can change signifigantly on the islands, so bilinear interpolation
# could downplay any drasticd changes in bathymetry for nearshore waves.
#
# pygrib shines when you need to observe messaging format or write to grib files, which neither
# applies to the usecase intended, so x-array it is.
#
# ## which data variables to use
#
# honestly, all data variables are useful. the two vars I considered scrapping were
# - dirc: current direction
# - spc: speed of current
#
# but these could be niche values not encompassed by most surf forecasting applications, so I think its valuable.
# it's a safety precaution too, and can tell how hard you will be working on paddling back out hahaha.
# need to check if the direction of the current is flowing TO or FROM. probably the same for all the other
# directions though. refer to the php [model viewer diagrams](https://polar.ncep.noaa.gov/nwps/nwpsloop.php?site=HFO&cg=4) to double check
#
# ### which swell height to portray...
#
# - shts: significant height of combined wind waves and swell
# - swh: significant height of total swell
#
# both are valuable. shts shows most accureate projection of nearshore wave height, including wind waves and storm surges. but doesn't nessicarily mean its "good", choppy wind waves aren't clean. if swh and shts are very similar to eachother, low wind chop and cleaner waves. both are important to show, just provide context on each one.
