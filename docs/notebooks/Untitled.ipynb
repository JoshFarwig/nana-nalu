# %%
### PacIOOS Tide model

# %%
import xarray as xr 
import numpy as np

# %%
url = "https://pae-paha.pacioos.hawaii.edu/thredds/dodsC/tide_mhi" 

ds = xr.open_dataset(url, chunks="auto") 

subset = dl.sel()
